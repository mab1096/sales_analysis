# %%
# Importing code from the txt file in jupyter: Now Jupyter will do these steps whenever you need to load data

import sys
sys.path.insert(1, '../src')
import mikes_work

# %%
import pandas as pd
pd.__version__
# Out:
# '1.1.3'

# %%
import pandas as pd

# ".." like in command prompt means go backwards in the folders

df_contracts = pd.read_csv('../data/contracts.csv')
df_contracts.head()
# Out:
#    contract_id  customer_id contract_start  contract_term      deposit  \
# 0            1          127      8/17/2019             12  $53,000.00
# 1            2          119      12/1/2019             22  $77,000.00
# 2            3          160       5/1/2019             15  $13,000.00
# 3            4            7      12/8/2019             23  $56,000.00
# 4            5          144      2/11/2019              7  $21,000.00
#
#    monthly_amt
# 0  $11,600.00
# 1  $14,600.00
# 2  $22,800.00
# 3  $11,400.00
# 4  $19,800.00

# %%
df_customers = pd.read_csv('../data/customers.csv')
df_customers.head()
# Out:
#    id       company         sector                                 industry  \
# 0   1     Bubblebox  Capital Goods            Military/Government/Technical
# 1   2          Izio         Energy                     Oil & Gas Production
# 2   3  Twitterworks            NaN                                      NaN
# 3   4          Viva    Health Care                    Major Pharmaceuticals
# 4   5   Jabberstorm     Technology  Computer Software: Prepackaged Software
#
#                       email                     address         city state  \
# 0  kyerson0@bizjournals.com             76 Randy Circle    San Diego    CA
# 1       farlet1@comcast.net  15360 Village Green Street      Spokane    WA
# 2        alerohan2@ox.ac.uk               29 Hovde Hill    Milwaukee    WI
# 3  wgiovanitti3@nytimes.com            074 Center Place       Topeka    KS
# 4         pscallon4@fc2.com                 4 Moose Way  Terre Haute    IN
#
#      zip
# 0  92170
# 1  99252
# 2  53234
# 3  66667
# ...

# %%
# We create a dictionary within the function {curly brackets = dictionary}

df_customers.rename(columns ={'id':'customer_id'}, inplace = True)
df_customers.head()
# Out:
#                   company         sector  \
# customer_id
# 1               Bubblebox  Capital Goods
# 2                    Izio         Energy
# 3            Twitterworks            NaN
# 4                    Viva    Health Care
# 5             Jabberstorm     Technology
#
#                                             industry  \
# customer_id
# 1                      Military/Government/Technical
# 2                               Oil & Gas Production
# 3                                                NaN
# 4                              Major Pharmaceuticals
# 5            Computer Software: Prepackaged Software
#
#                                 email                     address  \
# customer_id
# 1            kyerson0@bizjournals.com             76 Randy Circle
# 2                 farlet1@comcast.net  15360 Village Green Street
# 3                  alerohan2@ox.ac.uk               29 Hovde Hill
# 4            wgiovanitti3@nytimes.com            074 Center Place
# ...

# %%
# Setting the Index Key Variable

df_customers.set_index('customer_id', inplace=True)
df_contracts.set_index('customer_id', inplace=True)
df_customers.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-14-1fd29c7fcaaa> in <module>
#       1 # Setting the Index Key Variable
#       2
# ----> 3 df_customers.set_index('customer_id', inplace=True)
#       4 df_contracts.set_index('customer_id', inplace=True)
#       5 df_customers.head()
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4549
#    4550         if missing:
# -> 4551             raise KeyError(f"None of {missing} are in the columns")
#    4552
#    4553         if inplace:
#
# KeyError: "None of ['customer_id'] are in the columns"

# %%
df_contracts.head()
# Out:
#              contract_id contract_start  contract_term      deposit  \
# customer_id
# 127                    1      8/17/2019             12  $53,000.00
# 119                    2      12/1/2019             22  $77,000.00
# 160                    3       5/1/2019             15  $13,000.00
# 7                      4      12/8/2019             23  $56,000.00
# 144                    5      2/11/2019              7  $21,000.00
#
#              monthly_amt
# customer_id
# 127          $11,600.00
# 119          $14,600.00
# 160          $22,800.00
# 7            $11,400.00
# 144          $19,800.00

# %%
df = df_contracts.join(df_customers, how='left')
df.head()
# Out:
#              contract_id contract_start  contract_term      deposit  \
# customer_id
# 1                     41      5/31/2019             24  $86,000.00
# 1                    358      6/18/2019             13  $74,000.00
# 1                    400      8/11/2019             19  $38,000.00
# 1                    424      3/13/2019             15  $77,000.00
# 1                    438     10/16/2019             22  $39,000.00
#
#              monthly_amt    company         sector  \
# customer_id
# 1            $11,200.00   Bubblebox  Capital Goods
# 1            $19,000.00   Bubblebox  Capital Goods
# 1             $8,800.00   Bubblebox  Capital Goods
# 1            $14,300.00   Bubblebox  Capital Goods
# 1            $20,000.00   Bubblebox  Capital Goods
#
#                                   industry                     email  \
# customer_id
# 1            Military/Government/Technical  kyerson0@bizjournals.com
# ...

# %%
df = mikes_work.combine_data(df_contracts, df_customers)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-12-9cce44b71e5f> in <module>
# ----> 1 df = mikes_work.combine_data(df_contracts, df_customers)
#
# ~\bip-python-unh\sales_analysis\src\mikes_work.py in combine_data(df_contracts, df_customers)
#       8 def combine_data(df_contracts, df_customers):
#       9     df_customers.rename(columns ={'id':'customer_id'}, inplace = True)
# ---> 10     df_customers.set_index('customer_id', inplace=True)
#      11     df_contracts.set_index('customer_id', inplace=True)
#      12     df = df_contracts.join(df_customers, how='left')
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4549
#    4550         if missing:
# -> 4551             raise KeyError(f"None of {missing} are in the columns")
#    4552
#    4553         if inplace:
#
# ...

# %%
contract, cust = mikes_work.load_data()
contract.head()
