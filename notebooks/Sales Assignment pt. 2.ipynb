# %%
import pandas as pd

contracts = pd.read_csv("C:/Users/Michael Botelho/bip-python-unh/sales_analysis/data/contracts.csv")
customers = pd.read_csv("C:/Users/Michael Botelho/bip-python-unh/sales_analysis/data/customers.csv")
#print(contracts)
#print(customers)

#contracts.merge(customers,               how = "inner", on = "id")
#set_index('id', inplace = True)
#set_index('customer_id', inplace = True)

df = contracts.join(customers)
#print(df)


df.dtypes
df

############################################################################################

df['id'] = df['id'].astype(str)
df['customer_id'] = df['customer_id'].astype(str)










############################ GETS RID OF $ & Commas #########################################
import pandas as pd
#df = pd.DataFrame({'deposit': [" $1,557.97 ", "((45.22))"]})
#df['revenue'] = df['revenue'].replace('\$|,|\(|\)', '', regex=True)
df['deposit'] = df['deposit'].replace('[$,()]', '', regex=True)
#df['revenue'] = pd.to_numeric(df['revenue'])
df['deposit'] = df['deposit'].astype(float)
print(df)
print(df.dtypes)

#############################################################################################


total_sales = df.groupby(['state'])['deposit'].agg('mean', 'sum')
total_sales

#state_data.sort_values(by=['deposit'])
pd.set_option('display.max_columns', None)
total_sales

total_sales.columns = ['state', 'total sales']
total_sales


# ATTEMPTS AT CHANGING THE FUCKING DATA TYPE

#df['deposit'] = df.deposit.astype(float)
#df1 = df.astype({"deposit": float})
#df['deposit'] = df['deposit'].apply(lambda x: float(x.split()[0].replace(',', '')))
#df = pd.concat([df['deposit'].str.split()
             #          .str[0]
             #          .str.replace(',','').astype(float) for deposit in df], axis=1)
#df['deposit'] = df['deposit'].astype(int)
#print (df)

#import pandas as pd
#df = pd.DataFrame({'deposit': ["$1,557.97 "]})
#df['deposit'] = df['deposit'].replace('\$|,', '', regex=True)
#df['deposit'] = pd.to_numeric(df['deposit'])
#print(df)
#print(df.dtypes)
# Out:
#      contract_id customer_id contract_start  contract_term  deposit  \
# 0              1         127      8/17/2019             12  53000.0
# 1              2         119      12/1/2019             22  77000.0
# 2              3         160       5/1/2019             15  13000.0
# 3              4           7      12/8/2019             23  56000.0
# 4              5         144      2/11/2019              7  21000.0
# ..           ...         ...            ...            ...      ...
# 995          996          57      11/8/2019             15  38000.0
# 996          997         126      1/13/2019             20  28000.0
# 997          998          89       5/8/2019              7  73000.0
# 998          999          52      3/26/2019              7  63000.0
# 999         1000           3      3/19/2019             16  23000.0
#
#      monthly_amt   id       company         sector  \
# 0    $11,600.00   1.0     Bubblebox  Capital Goods
# ...

# %%
#total_sales.columns = ['state', 'total sales']
#total_sales

total_sales = df.groupby(['state'])['deposit'].agg('sum')
total_sales
# Out:
# state
# AK      68000.0
# AL     121000.0
# AR     112000.0
# AZ     376000.0
# CA    1186000.0
# CO     202000.0
# CT     235000.0
# DC     544000.0
# DE     187000.0
# FL     932000.0
# GA     281000.0
# HI      46000.0
# IA      79000.0
# ID     157000.0
# IL     210000.0
# IN      70000.0
# KS     415000.0
# KY      27000.0
# LA     372000.0
# MA      80000.0
# MD     273000.0
# ME      70000.0
# MI     329000.0
# MN     113000.0
# MO     447000.0
# MS     100000.0
# NC     313000.0
# NE     346000.0
# NJ      93000.0
# NM      20000.0
# NV     162000.0
# NY    1012000.0
# OH     374000.0
# OK     282000.0
# OR     353000.0
# PA     618000.0
# SC      57000.0
# TN     236000.0
# TX    1469000.0
# UT      19000.0
# VA     423000.0
# WA     484000.0
# WI     372000.0
# WV      59000.0
# Name: deposit, dtype: float64

# %%
import pandas as pd

contracts = pd.read_csv("C:/Users/Michael Botelho/bip-python-unh/sales_analysis/data/contracts.csv")
customers = pd.read_csv("C:/Users/Michael Botelho/bip-python-unh/sales_analysis/data/customers.csv")


pd.merge(contracts, customers, left_on="id", right_on="customer_id")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-18-70e26ac4ac52> in <module>
#       5
#       6
# ----> 7 pd.merge(contracts, customers, left_on="id", right_on="customer_id")
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      72     validate=None,
#      73 ) -> "DataFrame":
# ---> 74     op = _MergeOperation(
#      75         left,
#      76         right,
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     650             self.right_join_keys,
#     651             self.join_names,
# --> 652         ) = self._get_merge_keys()
#     653
# ...

# %%
import pandas as pd

contracts = pd.read_csv("C:/Users/Michael Botelho/bip-python-unh/sales_analysis/data/contracts.csv", delimiter =',', encoding="utf-8-sig")
customers = pd.read_csv("C:/Users/Michael Botelho/bip-python-unh/sales_analysis/data/customers.csv", delimiter =',', encoding="utf-8-sig")


# Changing Data Types

customers
customers['id'] = customers['id'].astype(str)
customers.dtypes

contracts['customer_id'] = contracts['customer_id'].astype(str)
contracts.dtypes
contracts


list(customers)
list(contracts)

customers.dtypes
contracts.dtypes

combined = pd.merge(customers, contracts, left_on='id', right_on='customer_id')
combined


# Just Merge it with the fuckin contract ID this is fuckin bullshit
#pd.merge(
#    customers.reset_index(),
#    contracts.reset_index(),
#on=['id', 'customer_id'])

#pd.merge(customers, contracts,
#        right_index = True, left_index = True)


#customers = customers.id.strip() 
#contracts = contracts.customer_id.strip()
#customers.merge(contracts,               
#                how = "inner", 
#                on = "id")
#set_index('id', inplace = False)
#set_index('customer_id', inplace = False)
#contracts.dtypes




#print(customers.dtypes)
#contracts.dtypes

#contracts['id'] = contracts['id'].astype(str)
#customers['customer_id'] = customers['customer_id'].astype(str)

############################ GETS RID OF $ & Commas #########################################
#df['deposit'] = df['deposit'].replace('[$,()]', '', regex=True)
#df['deposit'] = df['deposit'].astype(float)
#print(df)
#print(df.dtypes)

#############################################################################################
# Out:
#       id    company         sector  \
# 0      1  Bubblebox  Capital Goods
# 1      1  Bubblebox  Capital Goods
# 2      1  Bubblebox  Capital Goods
# 3      1  Bubblebox  Capital Goods
# 4      1  Bubblebox  Capital Goods
# ..   ...        ...            ...
# 995  200      Kwinu    Health Care
# 996  200      Kwinu    Health Care
# 997  200      Kwinu    Health Care
# 998  200      Kwinu    Health Care
# 999  200      Kwinu    Health Care
#
#                                               industry  \
# 0                        Military/Government/Technical
# 1                        Military/Government/Technical
# 2                        Military/Government/Technical
# 3                        Military/Government/Technical
# 4                        Military/Government/Technical
# ..                                                 ...
# 995  Biotechnology: Biological Products (No Diagnos...
# 996  Biotechnology: Biological Products (No Diagnos...
# ...

# %%
import pandas as pd

contracts = pd.read_csv("C:/Users/Michael Botelho/bip-python-unh/sales_analysis/data/contracts.csv")
customers = pd.read_csv("C:/Users/Michael Botelho/bip-python-unh/sales_analysis/data/customers.csv")
#print(contracts)
#print(customers)

#contracts.merge(customers,               how = "inner", on = "id")
#set_index('id', inplace = True)
#set_index('customer_id', inplace = True)

df = contracts.join(customers)
#print(df)


df.dtypes
df

############################################################################################

df['id'] = df['id'].astype(str)
df['customer_id'] = df['customer_id'].astype(str)










############################ GETS RID OF $ & Commas #########################################
import pandas as pd
#df = pd.DataFrame({'deposit': [" $1,557.97 ", "((45.22))"]})
#df['revenue'] = df['revenue'].replace('\$|,|\(|\)', '', regex=True)
df['deposit'] = df['deposit'].replace('[$,()]', '', regex=True)
#df['revenue'] = pd.to_numeric(df['revenue'])
df['deposit'] = df['deposit'].astype(float)
print(df)
print(df.dtypes)

#############################################################################################


total_sales = df.groupby(['state'])['deposit'].agg('mean', 'sum')
total_sales

#state_data.sort_values(by=['deposit'])
pd.set_option('display.max_columns', None)
total_sales

total_sales.columns = ['state', 'total sales']
total_sales


# ATTEMPTS AT CHANGING THE FUCKING DATA TYPE

#df['deposit'] = df.deposit.astype(float)
#df1 = df.astype({"deposit": float})
#df['deposit'] = df['deposit'].apply(lambda x: float(x.split()[0].replace(',', '')))
#df = pd.concat([df['deposit'].str.split()
             #          .str[0]
             #          .str.replace(',','').astype(float) for deposit in df], axis=1)
#df['deposit'] = df['deposit'].astype(int)
#print (df)

#import pandas as pd
#df = pd.DataFrame({'deposit': ["$1,557.97 "]})
#df['deposit'] = df['deposit'].replace('\$|,', '', regex=True)
#df['deposit'] = pd.to_numeric(df['deposit'])
#print(df)
#print(df.dtypes)


############################################################################################################################
############################################################################################################################


#total_sales.columns = ['state', 'total sales']
#total_sales

total_sales = df.groupby(['state'])['deposit'].agg('sum')
total_sales

############################################################################################################################
############################################################################################################################

import pandas as pd

contracts = pd.read_csv("C:/Users/Michael Botelho/bip-python-unh/sales_analysis/data/contracts.csv")
customers = pd.read_csv("C:/Users/Michael Botelho/bip-python-unh/sales_analysis/data/customers.csv")


pd.merge(contracts, customers, left_on="id", right_on="customer_id")


############################################################################################################################
############################################################################################################################

import pandas as pd

contracts = pd.read_csv("C:/Users/Michael Botelho/bip-python-unh/sales_analysis/data/contracts.csv", delimiter =',', encoding="utf-8-sig")
customers = pd.read_csv("C:/Users/Michael Botelho/bip-python-unh/sales_analysis/data/customers.csv", delimiter =',', encoding="utf-8-sig")


# Changing Data Types

customers
customers['id'] = customers['id'].astype(str)
customers.dtypes

contracts['customer_id'] = contracts['customer_id'].astype(str)
contracts.dtypes
contracts


list(customers)
list(contracts)

customers.dtypes
contracts.dtypes

combined = pd.merge(customers, contracts, left_on='id', right_on='customer_id')
combined
# Just Merge it with the fuckin contract ID this is fuckin bullshit
#pd.merge(
#    customers.reset_index(),
#    contracts.reset_index(),
#on=['id', 'customer_id'])

#pd.merge(customers, contracts,
#        right_index = True, left_index = True)


#customers = customers.id.strip() 
#contracts = contracts.customer_id.strip()
#customers.merge(contracts,               
#                how = "inner", 
#                on = "id")
#set_index('id', inplace = False)
#set_index('customer_id', inplace = False)
#contracts.dtypes




#print(customers.dtypes)
#contracts.dtypes

#contracts['id'] = contracts['id'].astype(str)
#customers['customer_id'] = customers['customer_id'].astype(str)

############################ GETS RID OF $ & Commas #########################################
#df['deposit'] = df['deposit'].replace('[$,()]', '', regex=True)
#df['deposit'] = df['deposit'].astype(float)
#print(df)
#print(df.dtypes)

#############################################################################################

# %%
import pandas as pd

contracts = pd.read_csv("C:/Users/Michael Botelho/bip-python-unh/sales_analysis/data/contracts.csv")
customers = pd.read_csv("C:/Users/Michael Botelho/bip-python-unh/sales_analysis/data/customers.csv")


# Join/Merge

# A
df = contracts.join(customers)
df.dtypes
df
df['id'] = df['id'].astype(str)
df['customer_id'] = df['customer_id'].astype(str)


df['deposit'] = df['deposit'].replace('[$,()]', '', regex=True)
df['deposit'] = df['deposit'].astype(float)
print(df)
print(df.dtypes)
total_sales = df.groupby(['state'])['deposit'].agg('mean', 'sum')
total_sales

#state_data.sort_values(by=['deposit'])
pd.set_option('display.max_columns', None)
total_sales

total_sales.columns = ['state', 'total sales']
total_sales

# B

#total_sales.columns = ['state', 'total sales']
#total_sales

total_sales = df.groupby(['state'])['deposit'].agg('sum')

# %%
import pandas as pd

contracts = pd.read_csv("C:/Users/Michael Botelho/bip-python-unh/sales_analysis/data/contracts.csv", delimiter =',', encoding="utf-8-sig")
customers = pd.read_csv("C:/Users/Michael Botelho/bip-python-unh/sales_analysis/data/customers.csv", delimiter =',', encoding="utf-8-sig")


# Changing Data Types

customers
customers['id'] = customers['id'].astype(str)
customers.dtypes

contracts['customer_id'] = contracts['customer_id'].astype(str)
contracts.dtypes
contracts


list(customers)
list(contracts)

customers.dtypes
contracts.dtypes

df = pd.merge(customers, contracts, left_on='id', right_on='customer_id')
df



#df = pd.DataFrame({'deposit': [" $1,557.97 ", "((45.22))"]})
#df['revenue'] = df['revenue'].replace('\$|,|\(|\)', '', regex=True)
df['deposit'] = df['deposit'].replace('[$,()]', '', regex=True)
#df['revenue'] = pd.to_numeric(df['revenue'])
df['deposit'] = df['deposit'].astype(float)
print(df)
print(df.dtypes)

total_sales = df.groupby(['state'])['deposit'].agg('mean', 'sum')
total_sales

#state_data.sort_values(by=['deposit'])
pd.set_option('display.max_columns', None)
total_sales

total_sales.columns = ['state', 'total sales']
total_sales
# Out:
#       id    company         sector  \
# 0      1  Bubblebox  Capital Goods
# 1      1  Bubblebox  Capital Goods
# 2      1  Bubblebox  Capital Goods
# 3      1  Bubblebox  Capital Goods
# 4      1  Bubblebox  Capital Goods
# ..   ...        ...            ...
# 995  200      Kwinu    Health Care
# 996  200      Kwinu    Health Care
# 997  200      Kwinu    Health Care
# 998  200      Kwinu    Health Care
# 999  200      Kwinu    Health Care
#
#                                               industry  \
# 0                        Military/Government/Technical
# 1                        Military/Government/Technical
# 2                        Military/Government/Technical
# 3                        Military/Government/Technical
# 4                        Military/Government/Technical
# ..                                                 ...
# 995  Biotechnology: Biological Products (No Diagnos...
# 996  Biotechnology: Biological Products (No Diagnos...
# ...
